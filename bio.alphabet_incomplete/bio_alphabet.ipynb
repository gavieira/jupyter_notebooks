# %% [markdown]
# # Biopython's alphabets

# %% [markdown]
# Biopython features different alphabets for the handling of nucleotide and/or aminocid data

# %% [markdown]
# In order to use this module, we need to import it first:

# %%
from Bio import Alphabet

# %% [markdown]
# After the import statement, we can use the **help()** function in order to get a quick description of the module and its features:

# %%
help(Alphabet)
# Out:
# Help on package Bio.Alphabet in Bio:
#
# NAME
#     Bio.Alphabet - Alphabets used in Seq objects etc to declare sequence type and letters.
#
# FILE
#     /home/gabriel/miniconda2/lib/python2.7/site-packages/Bio/Alphabet/__init__.py
#
# DESCRIPTION
#     This is used by sequences which contain a finite number of similar words.
#
# PACKAGE CONTENTS
#     IUPAC
#     Reduced
#
# CLASSES
#     __builtin__.object
#         Alphabet
#             SingleLetterAlphabet
#                 NucleotideAlphabet
#                     DNAAlphabet
#                     RNAAlphabet
#                 ProteinAlphabet
#                 SecondaryStructure
#             ThreeLetterProtein
#         AlphabetEncoder
#             Gapped
#             HasStopCodon
#
#     class Alphabet(__builtin__.object)
#      |  Generic alphabet base class.
#      |
#      |  This class is used as a base class for other types of alphabets.
#      |
#      |  Attributes:
# ...
